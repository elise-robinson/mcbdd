# %% [markdown]
# # Step 1

# %%
# !pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.11/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.7)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.0)

# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd

# Get all approved drugs
drug = new_client.drug
approved_drugs = drug.filter(max_phase=4)

# %%
df_drugs = pd.DataFrame(approved_drugs)
df_drugs.head()
# Out:
#                                           applicants  \
# 0  [Mylan Pharmaceuticals Inc, Teva Pharmaceutica...
# 1  [Perrigo R And D Co, Glaxosmithkline, L Perrig...
# 2  [Mankind Pharma Ltd, Bedford Laboratories Div ...
# 3  [Sun Pharmaceutical Industries Inc, Sanofi Ave...
# 4  [Navinta Llc, Aurobindo Pharma Ltd, Inwood Lab...
#
#                                   atc_classification  availability_type  \
# 0  [{'code': 'C02CA01', 'description': 'CARDIOVAS...                1.0
# 1  [{'code': 'N07BA01', 'description': 'NERVOUS S...                2.0
# 2  [{'code': 'S02AA16', 'description': 'SENSORY O...                1.0
# 3  [{'code': 'J01MB02', 'description': 'ANTIINFEC...                0.0
# 4  [{'code': 'M01AB51', 'description': 'MUSCULO-S...                1.0
#
#   biotherapeutic  black_box black_box_warning  chirality  drug_type  \
# 0           None          0                 0          2          1
# 1           None          0                 0          1          1
# 2           None          1                 1          0          1
# 3           None          0                 0          2          1
# 4           None          1                 1          2          1
#
#    first_approval  first_in_class  ... rule_of_five      sc_patent  \
# 0          1976.0               0  ...            1           None
# 1          1984.0               0  ...            1  US-8323683-B2
# 2          1990.0               0  ...            1           None
# 3          1964.0               0  ...            1           None
# 4          1965.0               0  ...            1  US-8734847-B2
#
#                                             synonyms topical usan_stem  \
# 0  [Prazosin hydrochloride (JAN, MI, USAN, USP), ...       0   -azosin
# 1  [Nicotine bitartrate (MI, USAN), Nicotine bita...       1      None
# 2       [Ofloxacin (BAN, INN, JAN, MI, USAN, USP), ]       1   -oxacin
# 3  [Nalidixate sodium (USAN), Nalidixic acid (BAN...       0      nal-
# 4  [Indometacin sodium (JAN), Indometacin sodium ...       1      None
#
#                                usan_stem_definition usan_stem_substem  \
# 0                 antihypertensives (prazosin type)  -azosin(-azosin)
# 1                                              None              None
# 2            antibacterials (quinolone derivatives)  -oxacin(-oxacin)
# 3  narcotic agonists/antagonists (normorphine type)        nal-(nal-)
# 4                                              None              None
#
#   usan_year  withdrawn_flag  atc_code_description
# 0    1968.0               0                   NaN
# 1    1985.0               0                   NaN
# 2    1984.0               0                   NaN
# 3    1962.0               0                   NaN
# 4    1963.0               0                   NaN
#
# [5 rows x 32 columns]

# %%
# Because the next step requires so much processing time, I am creating a shorter list of molecules here.
# If you wanted to run the whole list, you'd just have to continue with the entire "df_drugs".

df_drugs_500 = pd.DataFrame(list(approved_drugs)[:500])  # pulls the first 200 results quickly

# %%
# Use molecule_chembl_id to get molecule info (which includes pref_name)
molecule = new_client.molecule

# %%
# Create a list of molecules with pref_name
molecule_data = []
for mol_id in df_drugs_500['molecule_chembl_id']:
    try:
        mol = molecule.get(mol_id)
        molecule_data.append({
            'molecule_chembl_id': mol_id,
            'name': mol.get('pref_name'),
            'molecule_type': mol.get('molecule_type'),
            'approval_year': mol.get('first_approval')
        })
    except:
        continue

# %%
# Turn molecule_data into a df
df_molecules = pd.DataFrame(molecule_data)

# Convert approval year to integer
df_molecules['approval_year'] = df_molecules['approval_year'].astype('Int64')  # pandas nullable integer type
df_molecules.head()
# Out:
#   molecule_chembl_id            name   molecule_type  approval_year
# 0            CHEMBL2        PRAZOSIN  Small molecule           1976
# 1            CHEMBL3        NICOTINE  Small molecule           1984
# 2            CHEMBL4       OFLOXACIN  Small molecule           1990
# 3            CHEMBL5  NALIDIXIC ACID  Small molecule           1964
# 4            CHEMBL6    INDOMETHACIN  Small molecule           1965

# %%
# Sort df by approval year

df_molecules.sort_values('approval_year')
# Out:
#     molecule_chembl_id                name   molecule_type  approval_year
# 82           CHEMBL449        BUTABARBITAL  Small molecule           1939
# 401          CHEMBL700       SULFAPYRIDINE  Small molecule           1939
# 156           CHEMBL90           HISTAMINE  Small molecule           1939
# 65           CHEMBL439        SULFADIAZINE  Small molecule           1941
# 301          CHEMBL607          MEPERIDINE  Small molecule           1942
# ..                 ...                 ...             ...            ...
# 466          CHEMBL773             GLYCINE  Small molecule           <NA>
# 474       CHEMBL290106           BITHIONOL  Small molecule           <NA>
# 477        CHEMBL33864  LIPOIC ACID, ALPHA  Small molecule           <NA>
# 483        CHEMBL32800           FENOTEROL  Small molecule           <NA>
# 498        CHEMBL36715           PIRACETAM  Small molecule           <NA>
#
# [500 rows x 4 columns]

# %%
# Sort df by name

df_molecules.sort_values('name')
# Out:
#     molecule_chembl_id                  name   molecule_type  approval_year
# 346          CHEMBL642            ACEBUTOLOL  Small molecule           1984
# 236          CHEMBL112         ACETAMINOPHEN  Small molecule           1968
# 30            CHEMBL20         ACETAZOLAMIDE  Small molecule           1953
# 199          CHEMBL539           ACETIC ACID  Small molecule           <NA>
# 443          CHEMBL734  ACETOHYDROXAMIC ACID  Small molecule           1983
# ..                 ...                   ...             ...            ...
# 159           CHEMBL93              ZILEUTON  Small molecule           1996
# 416          CHEMBL708           ZIPRASIDONE  Small molecule           2001
# 306        CHEMBL19490             ZOMEPIRAC  Small molecule           1980
# 453          CHEMBL750            ZONISAMIDE  Small molecule           2000
# 427       CHEMBL285802              ZOTEPINE  Small molecule           <NA>
#
# [500 rows x 4 columns]

# %% [markdown]
# # Step 2

# %%
# Get drugs approved in 2014 and later
df_2014 = df_molecules[df_molecules['approval_year'] >= 2014].copy()
df_2014.head()
# Out:
#     molecule_chembl_id           name   molecule_type  approval_year
# 72            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 95            CHEMBL45      MELATONIN  Small molecule           2022
# 225          CHEMBL110   BENZNIDAZOLE  Small molecule           2017
# 283        CHEMBL17860     LOFEXIDINE  Small molecule           2018
# 300       CHEMBL278623    MACIMORELIN  Small molecule           2017

# %%
from chembl_webresource_client.new_client import new_client

activity = new_client.activity
target = new_client.target

target_data = []

for mol_id in df_2014['molecule_chembl_id']:
    try:
        acts = activity.filter(molecule_chembl_id=mol_id)
        target_ids = set(a['target_chembl_id'] for a in acts if 'target_chembl_id' in a)

        for tid in target_ids:
            t = target.get(tid)

            if t['target_components']:
                for comp in t['target_components']:
                    for xref in comp.get('target_component_xrefs', []):
                        if xref['xref_src_db'] == 'UniProt':
                            target_data.append({
                                'molecule_chembl_id': mol_id,
                                'uniprot_accession': xref['xref_id'],
                                'target_chembl_id': tid,
                                'target_name': t['pref_name']
                            })
    except Exception as e:
        print(f"Error with molecule {mol_id}: {e}")

# %%
df_targets = pd.DataFrame(target_data)
# df_targets.head(20)
df_final = pd.merge(df_2014, df_targets, on='molecule_chembl_id', how='left')
df_final.head(20)
# Out:
#    molecule_chembl_id           name   molecule_type  approval_year  \
# 0            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 1            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 2            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 3            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 4            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 5            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 6            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 7            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 8            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 9            CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 10           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 11           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 12           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 13           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 14           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 15           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 16           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 17           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 18           CHEMBL40  PHENOBARBITAL  Small molecule           2022
# 19           CHEMBL40  PHENOBARBITAL  Small molecule           2022
#
#    uniprot_accession target_chembl_id  \
# 0             B2RMT8       CHEMBL5748
# 1             Q14022       CHEMBL5748
# 2             Q5T2B1       CHEMBL5748
# 3             Q92500       CHEMBL5748
# 4             Q92798       CHEMBL5748
# 5             Q92887       CHEMBL5748
# 6             Q99663       CHEMBL5748
# 7             Q9UMS2       CHEMBL5748
# 8             O19043       CHEMBL4358
# 9             P12530       CHEMBL4358
# 10            Q6PSM0    CHEMBL1075135
# 11            P08246        CHEMBL248
# 12            P09649        CHEMBL248
# 13            Q6B0D9        CHEMBL248
# 14            Q6LDP5        CHEMBL248
# 15            A0ZXF9       CHEMBL2034
# 16            B0LPG8       CHEMBL2034
# 17            D3DQF4       CHEMBL2034
# 18            F5ATB7       CHEMBL2034
# 19            P04150       CHEMBL2034
#
#                                           target_name
# 0   Canalicular multispecific organic anion transp...
# 1   Canalicular multispecific organic anion transp...
# 2   Canalicular multispecific organic anion transp...
# 3   Canalicular multispecific organic anion transp...
# 4   Canalicular multispecific organic anion transp...
# 5   Canalicular multispecific organic anion transp...
# 6   Canalicular multispecific organic anion transp...
# 7   Canalicular multispecific organic anion transp...
# 8                        Arachidonate 15-lipoxygenase
# 9                        Arachidonate 15-lipoxygenase
# 10                    Multidrug resistance protein 1a
# 11                                 Leukocyte elastase
# 12                                 Leukocyte elastase
# 13                                 Leukocyte elastase
# 14                                 Leukocyte elastase
# 15                            Glucocorticoid receptor
# 16                            Glucocorticoid receptor
# 17                            Glucocorticoid receptor
# 18                            Glucocorticoid receptor
# 19                            Glucocorticoid receptor

# %% [markdown]
# # Step 3

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests

def fetch_uniprot_keywords(accession):
    url = f"https://rest.uniprot.org/uniprotkb/{accession}.json"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            keywords = data.get("keywords", [])
            return [kw.get("name") for kw in keywords]
        else:
            print(f"{accession}: HTTP {response.status_code}")
            return None
    except Exception as e:
        print(f"Error for {accession}: {e}")
        return None

# %%
unique_accessions = df_targets['uniprot_accession'].dropna().unique()

# %%
uniprot_keyword_data = []

for acc in unique_accessions:
    keywords = fetch_uniprot_keywords(acc)
    uniprot_keyword_data.append({
        'uniprot_accession': acc,
        'keywords': keywords
    })

# %%
df_keywords = pd.DataFrame(uniprot_keyword_data)
df_keywords.head(20)
# Out:
#    uniprot_accession                                           keywords
# 0             B2RMT8  [3D-structure, ATP-binding, Cell membrane, Dis...
# 1             Q14022  [3D-structure, ATP-binding, Cell membrane, Dis...
# 2             Q5T2B1  [3D-structure, ATP-binding, Cell membrane, Dis...
# 3             Q92500                                                 []
# 4             Q92798  [3D-structure, ATP-binding, Cell membrane, Dis...
# 5             Q92887  [3D-structure, ATP-binding, Cell membrane, Dis...
# 6             Q99663  [3D-structure, ATP-binding, Cell membrane, Dis...
# 7             Q9UMS2  [3D-structure, ATP-binding, Cell membrane, Dis...
# 8             O19043  [3D-structure, Calcium, Cell membrane, Cytopla...
# 9             P12530  [3D-structure, Calcium, Cell membrane, Cytopla...
# 10            Q6PSM0  [ATP-binding, Membrane, Nucleotide-binding, Tr...
# 11            P08246  [3D-structure, Cytoplasmic vesicle, Direct pro...
# 12            P09649  [3D-structure, Cytoplasmic vesicle, Direct pro...
# 13            Q6B0D9  [3D-structure, Cytoplasmic vesicle, Direct pro...
# 14            Q6LDP5  [3D-structure, Cytoplasmic vesicle, Direct pro...
# 15            A0ZXF9  [3D-structure, Acetylation, Alternative initia...
# 16            B0LPG8  [3D-structure, Acetylation, Alternative initia...
# 17            D3DQF4  [3D-structure, Acetylation, Alternative initia...
# 18            F5ATB7  [3D-structure, Acetylation, Alternative initia...
# 19            P04150  [3D-structure, Acetylation, Alternative initia...
